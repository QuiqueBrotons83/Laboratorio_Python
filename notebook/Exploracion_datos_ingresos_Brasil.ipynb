# %% [markdown]
# ### Importamos librerias para empezar a explorar los datos.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Empezamos a leer los datos de cada año y identificamos como funcionan.

# %%
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

df2013 = pd.read_csv('../../Panda/lab_python/datos/datos-2013.csv', sep =';', encoding="latin1")    
df2013
# Out:
#       CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                     63000  Advocacia-Geral da União         63000
# 1                     63000  Advocacia-Geral da União         63000
# 2                     63000  Advocacia-Geral da União         63000
# 3                     63000  Advocacia-Geral da União         63000
# 4                     63000  Advocacia-Geral da União         63000
# ...                     ...                       ...           ...
# 4493                  20000  Presidência da República         20101
# 4494                  20000  Presidência da República         64000
# 4495                  20000  Presidência da República         20101
# 4496                  20000  Presidência da República         20116
# 4497                  20000  Presidência da República         24208
#
#                                              NOME ÓRGÃO  \
# 0     Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
df2013.columns
# Veo que las columnas estan en portugues y creo un diccionario para que me las traduzca al español
traduccion_columnas = {
    'CÓDIGO ÓRGÃO SUPERIOR': 'CODIGO ORGANO SUPERIOR',
    'NOME ÓRGÃO SUPERIOR': 'NOMBRE ORGANO SUPERIOR',
    'CÓDIGO ÓRGÃO': 'CODIGO ORGANO',
    'NOME ÓRGÃO': 'NOMBRE ORGANO',
    'CÓDIGO UNIDADE GESTORA': 'CODIGO UNIDAD GESTORA',
    'NOME UNIDADE GESTORA': 'NOMBRE UNIDAD GESTORA',
    'CATEGORIA ECONÔMICA': 'CATEGORIA ECONOMICA',
    'ORIGEM RECEITA': 'ORIGEN INGRESO',
    'ESPÉCIE RECEITA': 'TIPO INGRESO',
    'DETALHAMENTO': 'DETALLE',
    'VALOR PREVISTO ATUALIZADO': 'VALOR PREVISTO ACTUALIZADO',
    'VALOR LANÇADO': 'VALOR REGISTRADO',
    'VALOR REALIZADO': 'VALOR REALIZADO',
    'PERCENTUAL REALIZADO': 'PORCENTAJE REALIZADO',
    'DATA LANÇAMENTO': 'FECHA REGISTRO',
    'ANO EXERCÍCIO': 'AÑO EJERCICIO'
}

# Cambia los nombres de las columnas
df2013.rename(columns=traduccion_columnas, inplace=True)

# Verifica el resultado
print(df2013.columns)
# Out:
# Index(['CODIGO ORGANO SUPERIOR', 'NOMBRE ORGANO SUPERIOR', 'CODIGO ORGANO',
#        'NOMBRE ORGANO', 'CODIGO UNIDAD GESTORA', 'NOMBRE UNIDAD GESTORA',
#        'CATEGORIA ECONOMICA', 'ORIGEN INGRESO', 'TIPO INGRESO', 'DETALLE',
#        'VALOR PREVISTO ACTUALIZADO', 'VALOR REGISTRADO', 'VALOR REALIZADO',
#        'PORCENTAJE REALIZADO', 'FECHA REGISTRO', 'AÑO EJERCICIO'],
#       dtype='object')

# %%
#Compruebo que esten cambiadas.
df2013.head()
# Out:
#    CODIGO ORGANO SUPERIOR    NOMBRE ORGANO SUPERIOR  CODIGO ORGANO  \
# 0                   63000  Advocacia-Geral da União          63000
# 1                   63000  Advocacia-Geral da União          63000
# 2                   63000  Advocacia-Geral da União          63000
# 3                   63000  Advocacia-Geral da União          63000
# 4                   63000  Advocacia-Geral da União          63000
#
#                                        NOMBRE ORGANO  CODIGO UNIDAD GESTORA  \
# 0  Advocacia-Geral da União - Unidades com víncul...                 110060
# 1  Advocacia-Geral da União - Unidades com víncul...                 110060
# 2  Advocacia-Geral da União - Unidades com víncul...                 110060
# 3  Advocacia-Geral da União - Unidades com víncul...                 110060
# 4  Advocacia-Geral da União - Unidades com víncul...                 110060
#
#                            NOMBRE UNIDAD GESTORA CATEGORIA ECONOMICA  \
# ...

# %%
# Hago un info para ver las columnas y el tipo de datos.
df2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4498 entries, 0 to 4497
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CODIGO ORGANO SUPERIOR      4498 non-null   int64
#  1   NOMBRE ORGANO SUPERIOR      4498 non-null   object
#  2   CODIGO ORGANO               4498 non-null   int64
#  3   NOMBRE ORGANO               4498 non-null   object
#  4   CODIGO UNIDAD GESTORA       4498 non-null   int64
#  5   NOMBRE UNIDAD GESTORA       4498 non-null   object
#  6   CATEGORIA ECONOMICA         4498 non-null   object
#  7   ORIGEN INGRESO              4498 non-null   object
#  8   TIPO INGRESO                4498 non-null   object
#  9   DETALLE                     4498 non-null   object
#  10  VALOR PREVISTO ACTUALIZADO  4498 non-null   object
#  11  VALOR REGISTRADO            4498 non-null   object
#  12  VALOR REALIZADO             4498 non-null   object
# ...

# %%
# Veo que la columna FECHA REGISTRO esta en formato object y la cambio a tipo Fecha
df2013['FECHA REGISTRO'] = pd.to_datetime(df2013['FECHA REGISTRO'], format='mixed', errors='coerce')
df2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4498 entries, 0 to 4497
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CODIGO ORGANO SUPERIOR      4498 non-null   int64
#  1   NOMBRE ORGANO SUPERIOR      4498 non-null   object
#  2   CODIGO ORGANO               4498 non-null   int64
#  3   NOMBRE ORGANO               4498 non-null   object
#  4   CODIGO UNIDAD GESTORA       4498 non-null   int64
#  5   NOMBRE UNIDAD GESTORA       4498 non-null   object
#  6   CATEGORIA ECONOMICA         4498 non-null   object
#  7   ORIGEN INGRESO              4498 non-null   object
#  8   TIPO INGRESO                4498 non-null   object
#  9   DETALLE                     4498 non-null   object
#  10  VALOR PREVISTO ACTUALIZADO  4498 non-null   object
#  11  VALOR REGISTRADO            4498 non-null   object
#  12  VALOR REALIZADO             4498 non-null   object
# ...

# %%
# Hago  una eda numerica y compruebo la calidad de los datos numericos, y me doy cuenta que la columna fecha registro tiene el mismo valor en todas las filas por lo que veo que no es un dato muy relevante.
df2013.describe()
# Out:
#        CODIGO ORGANO SUPERIOR  CODIGO ORGANO  CODIGO UNIDAD GESTORA  \
# count             4498.000000    4498.000000            4498.000000
# mean             31729.657626   31447.970431          233059.797910
# min              20000.000000   20101.000000          110005.000000
# 25%              25000.000000   25916.000000          153173.000000
# 50%              26000.000000   26292.000000          160075.000000
# 75%              36000.000000   35000.000000          254420.000000
# max              81000.000000   91214.000000          913001.000000
# std              10691.972258   10798.289531          141561.057724
#
#             FECHA REGISTRO  AÑO EJERCICIO
# count                 4498         4498.0
# mean   2013-12-31 00:00:00         2013.0
# min    2013-12-31 00:00:00         2013.0
# 25%    2013-12-31 00:00:00         2013.0
# 50%    2013-12-31 00:00:00         2013.0
# 75%    2013-12-31 00:00:00         2013.0
# max    2013-12-31 00:00:00         2013.0
# ...

# %%
# Aquí hago un print para que me sume los valores nulos por columna.
print(df2013.isnull().sum())
# Out:
# CODIGO ORGANO SUPERIOR        0
# NOMBRE ORGANO SUPERIOR        0
# CODIGO ORGANO                 0
# NOMBRE ORGANO                 0
# CODIGO UNIDAD GESTORA         0
# NOMBRE UNIDAD GESTORA         0
# CATEGORIA ECONOMICA           0
# ORIGEN INGRESO                0
# TIPO INGRESO                  0
# DETALLE                       0
# VALOR PREVISTO ACTUALIZADO    0
# VALOR REGISTRADO              0
# VALOR REALIZADO               0
# PORCENTAJE REALIZADO          0
# FECHA REGISTRO                0
# AÑO EJERCICIO                 0
# dtype: int64

# %%
# Aquí hago lo mismo para que me sume y muestre los valores duplicados del data frame
print(f"Valores duplicados {df2013.duplicated().sum()}")
# Out:
# Valores duplicados 0

# %%
df2014 = pd.read_csv('../../Panda/lab_python/datos/datos-2014.csv', sep =';', encoding="latin1")    
df2014.columns
# Veo que las columnas estan en portugues y creo un diccionario para que me las traduzca al español
traduccion_columnas = {
    'CÓDIGO ÓRGÃO SUPERIOR': 'CODIGO ORGANO SUPERIOR',
    'NOME ÓRGÃO SUPERIOR': 'NOMBRE ORGANO SUPERIOR',
    'CÓDIGO ÓRGÃO': 'CODIGO ORGANO',
    'NOME ÓRGÃO': 'NOMBRE ORGANO',
    'CÓDIGO UNIDADE GESTORA': 'CODIGO UNIDAD GESTORA',
    'NOME UNIDADE GESTORA': 'NOMBRE UNIDAD GESTORA',
    'CATEGORIA ECONÔMICA': 'CATEGORIA ECONOMICA',
    'ORIGEM RECEITA': 'ORIGEN INGRESO',
    'ESPÉCIE RECEITA': 'TIPO INGRESO',
    'DETALHAMENTO': 'DETALLE',
    'VALOR PREVISTO ATUALIZADO': 'VALOR PREVISTO ACTUALIZADO',
    'VALOR LANÇADO': 'VALOR REGISTRADO',
    'VALOR REALIZADO': 'VALOR REALIZADO',
    'PERCENTUAL REALIZADO': 'PORCENTAJE REALIZADO',
    'DATA LANÇAMENTO': 'FECHA REGISTRO',
    'ANO EXERCÍCIO': 'AÑO EJERCICIO'
}

# Cambia los nombres de las columnas
df2014.rename(columns=traduccion_columnas, inplace=True)

# Verifica el resultado
print(df2014.columns)
# Out:
# Index(['CODIGO ORGANO SUPERIOR', 'NOMBRE ORGANO SUPERIOR', 'CODIGO ORGANO',
#        'NOMBRE ORGANO', 'CODIGO UNIDAD GESTORA', 'NOMBRE UNIDAD GESTORA',
#        'CATEGORIA ECONOMICA', 'ORIGEN INGRESO', 'TIPO INGRESO', 'DETALLE',
#        'VALOR PREVISTO ACTUALIZADO', 'VALOR REGISTRADO', 'VALOR REALIZADO',
#        'PORCENTAJE REALIZADO', 'FECHA REGISTRO', 'AÑO EJERCICIO'],
#       dtype='object')

# %%
df2015 = pd.read_csv('../../Panda/lab_python/datos/datos-2015.csv', sep =';', encoding="latin1")
df2015.head(2) 
df2015.columns
# Veo que las columnas estan en portugues y creo un diccionario para que me las traduzca al español
traduccion_columnas = {
    'CÓDIGO ÓRGÃO SUPERIOR': 'CODIGO ORGANO SUPERIOR',
    'NOME ÓRGÃO SUPERIOR': 'NOMBRE ORGANO SUPERIOR',
    'CÓDIGO ÓRGÃO': 'CODIGO ORGANO',
    'NOME ÓRGÃO': 'NOMBRE ORGANO',
    'CÓDIGO UNIDADE GESTORA': 'CODIGO UNIDAD GESTORA',
    'NOME UNIDADE GESTORA': 'NOMBRE UNIDAD GESTORA',
    'CATEGORIA ECONÔMICA': 'CATEGORIA ECONOMICA',
    'ORIGEM RECEITA': 'ORIGEN INGRESO',
    'ESPÉCIE RECEITA': 'TIPO INGRESO',
    'DETALHAMENTO': 'DETALLE',
    'VALOR PREVISTO ATUALIZADO': 'VALOR PREVISTO ACTUALIZADO',
    'VALOR LANÇADO': 'VALOR REGISTRADO',
    'VALOR REALIZADO': 'VALOR REALIZADO',
    'PERCENTUAL REALIZADO': 'PORCENTAJE REALIZADO',
    'DATA LANÇAMENTO': 'FECHA REGISTRO',
    'ANO EXERCÍCIO': 'AÑO EJERCICIO'
}

# Cambia los nombres de las columnas
df2015.rename(columns=traduccion_columnas, inplace=True)

# Verifica el resultado
print(df2015.columns)
# Out:
# Index(['CODIGO ORGANO SUPERIOR', 'NOMBRE ORGANO SUPERIOR', 'CODIGO ORGANO',
#        'NOMBRE ORGANO', 'CODIGO UNIDAD GESTORA', 'NOMBRE UNIDAD GESTORA',
#        'CATEGORIA ECONOMICA', 'ORIGEN INGRESO', 'TIPO INGRESO', 'DETALLE',
#        'VALOR PREVISTO ACTUALIZADO', 'VALOR REGISTRADO', 'VALOR REALIZADO',
#        'PORCENTAJE REALIZADO', 'FECHA REGISTRO', 'AÑO EJERCICIO'],
#       dtype='object')

# %%
df2016 = pd.read_csv('../../Panda/lab_python/datos/datos-2016.csv', sep =';', encoding="latin1")    
df2016.head(2) 
df2016.columns
# Veo que las columnas estan en portugues y creo un diccionario para que me las traduzca al español
traduccion_columnas = {
    'CÓDIGO ÓRGÃO SUPERIOR': 'CODIGO ORGANO SUPERIOR',
    'NOME ÓRGÃO SUPERIOR': 'NOMBRE ORGANO SUPERIOR',
    'CÓDIGO ÓRGÃO': 'CODIGO ORGANO',
    'NOME ÓRGÃO': 'NOMBRE ORGANO',
    'CÓDIGO UNIDADE GESTORA': 'CODIGO UNIDAD GESTORA',
    'NOME UNIDADE GESTORA': 'NOMBRE UNIDAD GESTORA',
    'CATEGORIA ECONÔMICA': 'CATEGORIA ECONOMICA',
    'ORIGEM RECEITA': 'ORIGEN INGRESO',
    'ESPÉCIE RECEITA': 'TIPO INGRESO',
    'DETALHAMENTO': 'DETALLE',
    'VALOR PREVISTO ATUALIZADO': 'VALOR PREVISTO ACTUALIZADO',
    'VALOR LANÇADO': 'VALOR REGISTRADO',
    'VALOR REALIZADO': 'VALOR REALIZADO',
    'PERCENTUAL REALIZADO': 'PORCENTAJE REALIZADO',
    'DATA LANÇAMENTO': 'FECHA REGISTRO',
    'ANO EXERCÍCIO': 'AÑO EJERCICIO'
}

# Cambia los nombres de las columnas
df2016.rename(columns=traduccion_columnas, inplace=True)

# Verifica el resultado
print(df2016.columns)
# Out:
# Index(['CODIGO ORGANO SUPERIOR', 'NOMBRE ORGANO SUPERIOR', 'CODIGO ORGANO',
#        'NOMBRE ORGANO', 'CODIGO UNIDAD GESTORA', 'NOMBRE UNIDAD GESTORA',
#        'CATEGORIA ECONOMICA', 'ORIGEN INGRESO', 'TIPO INGRESO', 'DETALLE',
#        'VALOR PREVISTO ACTUALIZADO', 'VALOR REGISTRADO', 'VALOR REALIZADO',
#        'PORCENTAJE REALIZADO', 'FECHA REGISTRO', 'AÑO EJERCICIO'],
#       dtype='object')

# %%
df2017 = pd.read_csv('../../Panda/lab_python/datos/datos-2017.csv', sep =';', encoding="latin1")    
df2017.head(2) 
df2017.columns
# Veo que las columnas estan en portugues y creo un diccionario para que me las traduzca al español
traduccion_columnas = {
    'CÓDIGO ÓRGÃO SUPERIOR': 'CODIGO ORGANO SUPERIOR',
    'NOME ÓRGÃO SUPERIOR': 'NOMBRE ORGANO SUPERIOR',
    'CÓDIGO ÓRGÃO': 'CODIGO ORGANO',
    'NOME ÓRGÃO': 'NOMBRE ORGANO',
    'CÓDIGO UNIDADE GESTORA': 'CODIGO UNIDAD GESTORA',
    'NOME UNIDADE GESTORA': 'NOMBRE UNIDAD GESTORA',
    'CATEGORIA ECONÔMICA': 'CATEGORIA ECONOMICA',
    'ORIGEM RECEITA': 'ORIGEN INGRESO',
    'ESPÉCIE RECEITA': 'TIPO INGRESO',
    'DETALHAMENTO': 'DETALLE',
    'VALOR PREVISTO ATUALIZADO': 'VALOR PREVISTO ACTUALIZADO',
    'VALOR LANÇADO': 'VALOR REGISTRADO',
    'VALOR REALIZADO': 'VALOR REALIZADO',
    'PERCENTUAL REALIZADO': 'PORCENTAJE REALIZADO',
    'DATA LANÇAMENTO': 'FECHA REGISTRO',
    'ANO EXERCÍCIO': 'AÑO EJERCICIO'
}

# Cambia los nombres de las columnas
df2017.rename(columns=traduccion_columnas, inplace=True)

# Verifica el resultado
print(df2017.columns)
# Out:
# Index(['CODIGO ORGANO SUPERIOR', 'NOMBRE ORGANO SUPERIOR', 'CODIGO ORGANO',
#        'NOMBRE ORGANO', 'CODIGO UNIDAD GESTORA', 'NOMBRE UNIDAD GESTORA',
#        'CATEGORIA ECONOMICA', 'ORIGEN INGRESO', 'TIPO INGRESO', 'DETALLE',
#        'VALOR PREVISTO ACTUALIZADO', 'VALOR REGISTRADO', 'VALOR REALIZADO',
#        'PORCENTAJE REALIZADO', 'FECHA REGISTRO', 'AÑO EJERCICIO'],
#       dtype='object')

# %%
df2018 = pd.read_csv('../../Panda/lab_python/datos/datos-2018.csv', sep =';', encoding="latin1")    
df2018.head(2) 
df2018.columns
# Veo que las columnas estan en portugues y creo un diccionario para que me las traduzca al español
traduccion_columnas = {
    'CÓDIGO ÓRGÃO SUPERIOR': 'CODIGO ORGANO SUPERIOR',
    'NOME ÓRGÃO SUPERIOR': 'NOMBRE ORGANO SUPERIOR',
    'CÓDIGO ÓRGÃO': 'CODIGO ORGANO',
    'NOME ÓRGÃO': 'NOMBRE ORGANO',
    'CÓDIGO UNIDADE GESTORA': 'CODIGO UNIDAD GESTORA',
    'NOME UNIDADE GESTORA': 'NOMBRE UNIDAD GESTORA',
    'CATEGORIA ECONÔMICA': 'CATEGORIA ECONOMICA',
    'ORIGEM RECEITA': 'ORIGEN INGRESO',
    'ESPÉCIE RECEITA': 'TIPO INGRESO',
    'DETALHAMENTO': 'DETALLE',
    'VALOR PREVISTO ATUALIZADO': 'VALOR PREVISTO ACTUALIZADO',
    'VALOR LANÇADO': 'VALOR REGISTRADO',
    'VALOR REALIZADO': 'VALOR REALIZADO',
    'PERCENTUAL REALIZADO': 'PORCENTAJE REALIZADO',
    'DATA LANÇAMENTO': 'FECHA REGISTRO',
    'ANO EXERCÍCIO': 'AÑO EJERCICIO'
}

# Cambia los nombres de las columnas
df2018.rename(columns=traduccion_columnas, inplace=True)

# Verifica el resultado
print(df2018.columns)
# Out:
# Index(['CODIGO ORGANO SUPERIOR', 'NOMBRE ORGANO SUPERIOR', 'CODIGO ORGANO',
#        'NOMBRE ORGANO', 'CODIGO UNIDAD GESTORA', 'NOMBRE UNIDAD GESTORA',
#        'CATEGORIA ECONOMICA', 'ORIGEN INGRESO', 'TIPO INGRESO', 'DETALLE',
#        'VALOR PREVISTO ACTUALIZADO', 'VALOR REGISTRADO', 'VALOR REALIZADO',
#        'PORCENTAJE REALIZADO', 'FECHA REGISTRO', 'AÑO EJERCICIO'],
#       dtype='object')

# %%
df2019 = pd.read_csv('../../Panda/lab_python/datos/datos-2019.csv', sep =';', encoding="latin1")    
df2019.head(2) 
df2019.columns
# Veo que las columnas estan en portugues y creo un diccionario para que me las traduzca al español
traduccion_columnas = {
    'CÓDIGO ÓRGÃO SUPERIOR': 'CODIGO ORGANO SUPERIOR',
    'NOME ÓRGÃO SUPERIOR': 'NOMBRE ORGANO SUPERIOR',
    'CÓDIGO ÓRGÃO': 'CODIGO ORGANO',
    'NOME ÓRGÃO': 'NOMBRE ORGANO',
    'CÓDIGO UNIDADE GESTORA': 'CODIGO UNIDAD GESTORA',
    'NOME UNIDADE GESTORA': 'NOMBRE UNIDAD GESTORA',
    'CATEGORIA ECONÔMICA': 'CATEGORIA ECONOMICA',
    'ORIGEM RECEITA': 'ORIGEN INGRESO',
    'ESPÉCIE RECEITA': 'TIPO INGRESO',
    'DETALHAMENTO': 'DETALLE',
    'VALOR PREVISTO ATUALIZADO': 'VALOR PREVISTO ACTUALIZADO',
    'VALOR LANÇADO': 'VALOR REGISTRADO',
    'VALOR REALIZADO': 'VALOR REALIZADO',
    'PERCENTUAL REALIZADO': 'PORCENTAJE REALIZADO',
    'DATA LANÇAMENTO': 'FECHA REGISTRO',
    'ANO EXERCÍCIO': 'AÑO EJERCICIO'
}

# Cambia los nombres de las columnas
df2019.rename(columns=traduccion_columnas, inplace=True)

# Verifica el resultado
print(df2019.columns)
# Out:
# Index(['CODIGO ORGANO SUPERIOR', 'NOMBRE ORGANO SUPERIOR', 'CODIGO ORGANO',
#        'NOMBRE ORGANO', 'CODIGO UNIDAD GESTORA', 'NOMBRE UNIDAD GESTORA',
#        'CATEGORIA ECONOMICA', 'ORIGEN INGRESO', 'TIPO INGRESO', 'DETALLE',
#        'VALOR PREVISTO ACTUALIZADO', 'VALOR REGISTRADO', 'VALOR REALIZADO',
#        'PORCENTAJE REALIZADO', 'FECHA REGISTRO', 'AÑO EJERCICIO'],
#       dtype='object')

# %%
df2020 = pd.read_csv('../../Panda/lab_python/datos/datos-2020.csv', sep =';', encoding="latin1")    
df2020.head(2) 
df2020.columns
# Veo que las columnas estan en portugues y creo un diccionario para que me las traduzca al español
traduccion_columnas = {
    'CÓDIGO ÓRGÃO SUPERIOR': 'CODIGO ORGANO SUPERIOR',
    'NOME ÓRGÃO SUPERIOR': 'NOMBRE ORGANO SUPERIOR',
    'CÓDIGO ÓRGÃO': 'CODIGO ORGANO',
    'NOME ÓRGÃO': 'NOMBRE ORGANO',
    'CÓDIGO UNIDADE GESTORA': 'CODIGO UNIDAD GESTORA',
    'NOME UNIDADE GESTORA': 'NOMBRE UNIDAD GESTORA',
    'CATEGORIA ECONÔMICA': 'CATEGORIA ECONOMICA',
    'ORIGEM RECEITA': 'ORIGEN INGRESO',
    'ESPÉCIE RECEITA': 'TIPO INGRESO',
    'DETALHAMENTO': 'DETALLE',
    'VALOR PREVISTO ATUALIZADO': 'VALOR PREVISTO ACTUALIZADO',
    'VALOR LANÇADO': 'VALOR REGISTRADO',
    'VALOR REALIZADO': 'VALOR REALIZADO',
    'PERCENTUAL REALIZADO': 'PORCENTAJE REALIZADO',
    'DATA LANÇAMENTO': 'FECHA REGISTRO',
    'ANO EXERCÍCIO': 'AÑO EJERCICIO'
}

# Cambia los nombres de las columnas
df2020.rename(columns=traduccion_columnas, inplace=True)

# Verifica el resultado
print(df2020.columns)
# Out:
# Index(['CODIGO ORGANO SUPERIOR', 'NOMBRE ORGANO SUPERIOR', 'CODIGO ORGANO',
#        'NOMBRE ORGANO', 'CODIGO UNIDAD GESTORA', 'NOMBRE UNIDAD GESTORA',
#        'CATEGORIA ECONOMICA', 'ORIGEN INGRESO', 'TIPO INGRESO', 'DETALLE',
#        'VALOR PREVISTO ACTUALIZADO', 'VALOR REGISTRADO', 'VALOR REALIZADO',
#        'PORCENTAJE REALIZADO', 'FECHA REGISTRO', 'AÑO EJERCICIO'],
#       dtype='object')

# %%
df2021 = pd.read_csv('../../Panda/lab_python/datos/datos-2021.csv', sep =';', encoding="latin1")    
df2021.head(2)
df2021.columns
# Veo que las columnas estan en portugues y creo un diccionario para que me las traduzca al español
traduccion_columnas = {
    'CÓDIGO ÓRGÃO SUPERIOR': 'CODIGO ORGANO SUPERIOR',
    'NOME ÓRGÃO SUPERIOR': 'NOMBRE ORGANO SUPERIOR',
    'CÓDIGO ÓRGÃO': 'CODIGO ORGANO',
    'NOME ÓRGÃO': 'NOMBRE ORGANO',
    'CÓDIGO UNIDADE GESTORA': 'CODIGO UNIDAD GESTORA',
    'NOME UNIDADE GESTORA': 'NOMBRE UNIDAD GESTORA',
    'CATEGORIA ECONÔMICA': 'CATEGORIA ECONOMICA',
    'ORIGEM RECEITA': 'ORIGEN INGRESO',
    'ESPÉCIE RECEITA': 'TIPO INGRESO',
    'DETALHAMENTO': 'DETALLE',
    'VALOR PREVISTO ATUALIZADO': 'VALOR PREVISTO ACTUALIZADO',
    'VALOR LANÇADO': 'VALOR REGISTRADO',
    'VALOR REALIZADO': 'VALOR REALIZADO',
    'PERCENTUAL REALIZADO': 'PORCENTAJE REALIZADO',
    'DATA LANÇAMENTO': 'FECHA REGISTRO',
    'ANO EXERCÍCIO': 'AÑO EJERCICIO'
}

# Cambia los nombres de las columnas
df2021.rename(columns=traduccion_columnas, inplace=True)

# Verifica el resultado
print(df2021.columns)
# Out:
# Index(['CODIGO ORGANO SUPERIOR', 'NOMBRE ORGANO SUPERIOR', 'CODIGO ORGANO',
#        'NOMBRE ORGANO', 'CODIGO UNIDAD GESTORA', 'NOMBRE UNIDAD GESTORA',
#        'CATEGORIA ECONOMICA', 'ORIGEN INGRESO', 'TIPO INGRESO', 'DETALLE',
#        'VALOR PREVISTO ACTUALIZADO', 'VALOR REGISTRADO', 'VALOR REALIZADO',
#        'PORCENTAJE REALIZADO', 'FECHA REGISTRO', 'AÑO EJERCICIO'],
#       dtype='object')

# %% [markdown]
# ### Al comprobar el df2013 y ver que tienen todos las mismas columnas y todas con el mismo nombre decido hacer ya la union de los datos.

# %%
# Primero creo una lista con los data frame para unirlos
df_años = [df2013, df2014, df2015, df2016, df2017, df2018, df2019, df2020, df2021]

df_unido = pd.concat(df_años, ignore_index=True)

df_unido.columns
# Out:
# Index(['CODIGO ORGANO SUPERIOR', 'NOMBRE ORGANO SUPERIOR', 'CODIGO ORGANO',
#        'NOMBRE ORGANO', 'CODIGO UNIDAD GESTORA', 'NOMBRE UNIDAD GESTORA',
#        'CATEGORIA ECONOMICA', 'ORIGEN INGRESO', 'TIPO INGRESO', 'DETALLE',
#        'VALOR PREVISTO ACTUALIZADO', 'VALOR REGISTRADO', 'VALOR REALIZADO',
#        'PORCENTAJE REALIZADO', 'FECHA REGISTRO', 'AÑO EJERCICIO'],
#       dtype='object')

# %%
df_unido.shape # Hago un shape para ver los datos vemos que tenemos 16 columnas y 1026299 filas.
# Out:
# (1026299, 16)

# %%
df_unido.sample(10)
# Out:
#          CODIGO ORGANO SUPERIOR  \
# 460246                    25000
# 1024054                   54000
# 815910                    26000
# 384746                    53000
# 802065                    25000
# 978095                    26000
# 110104                    26000
# 353138                    30000
# 892540                    22000
# 121184                    26000
#
#                                 NOMBRE ORGANO SUPERIOR  CODIGO ORGANO  \
# 460246                          Ministério da Economia          25000
# 1024054                          Ministério do Turismo          34902
# 815910                          Ministério da Educação          26245
# 384746          Ministério do Desenvolvimento Regional          22204
# 802065                          Ministério da Economia          37904
# 978095                          Ministério da Educação          26418
# 110104                          Ministério da Educação          26241
# ...

# %%
# Guardo los datos unidos para empezar a trabajar con ellos.
#df_unido.to_csv("df_unido.csv", index=False) # Como ya lo he ejecutado lo dejo con una almohadilla para que no ejecute cada vez esa linea de codigo.

# %%
df_unido.columns.isnull().sum()
# Out:
# np.int64(0)

# %%
df_unido.columns.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_unido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1026299 entries, 0 to 1026298
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   CODIGO ORGANO SUPERIOR      1026299 non-null  int64
#  1   NOMBRE ORGANO SUPERIOR      1026299 non-null  object
#  2   CODIGO ORGANO               1026299 non-null  int64
#  3   NOMBRE ORGANO               1026299 non-null  object
#  4   CODIGO UNIDAD GESTORA       1026299 non-null  int64
#  5   NOMBRE UNIDAD GESTORA       1026299 non-null  object
#  6   CATEGORIA ECONOMICA         1026299 non-null  object
#  7   ORIGEN INGRESO              1026299 non-null  object
#  8   TIPO INGRESO                1026299 non-null  object
#  9   DETALLE                     1026299 non-null  object
#  10  VALOR PREVISTO ACTUALIZADO  1026299 non-null  object
#  11  VALOR REGISTRADO            1026299 non-null  object
# ...

# %% [markdown]
# ## Queda terminado la primera exploración de los datos y decido crear un nuevo repositorio para continuar el trabajo.
